# %% [markdown]
# #### Basic usage of Tensorboard with minist data

# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import argparse
import sys
FLAGS = None

# %%
def train():
    tf.reset_default_graph()
    #import data
    mnist = input_data.read_data_sets(FLAGS.data_dir,
                                    one_hot=True,
                                    fake_data=FLAGS.fake_data)

    sess = tf.InteractiveSession()
    # Create a multilayer model.
    # Input placeholders
    with tf.name_scope('input'):
        x = tf.placeholder(tf.float32, [None, 784], name='x-input')
        y_ = tf.placeholder(tf.float32, [None, 10], name='y-input')

    with tf.name_scope('input_reshape'):
        image_shaped_input = tf.reshape(x, [-1, 28, 28, 1])
        tf.summary.image('input', image_shaped_input, 10)

    # define initial weight variables 
    def weight_variable(shape):
        """Create a weight variable with appropriate initialization."""
        initial = tf.truncated_normal(shape, stddev=0.1)
        return tf.Variable(initial)

    def bias_variable(shape):
        """Create a bias variable with appropriate initialization."""
        initial = tf.constant(0.1, shape=shape)
        return tf.Variable(initial)
    
    ###################################
    ##### This is for tensorboard
    ##################################
    def variable_summaries(var):
        """Attach a lot of summaries to a Tensor (for TensorBoard visualization)."""
        with tf.name_scope('summaries'):
            mean = tf.reduce_mean(var)
            tf.summary.scalar('mean', mean)
            with tf.name_scope('stddev'):
                stddev = tf.sqrt(tf.reduce_mean(tf.square(var - mean)))
            tf.summary.scalar('stddev', stddev)
            tf.summary.scalar('max', tf.reduce_max(var))
            tf.summary.scalar('min', tf.reduce_min(var))
            tf.summary.histogram('histogram', var)

    def nn_layer(input_tensor, input_dim, output_dim, layer_name, act=tf.nn.relu):
        """Reusable code for making a simple neural net layer.
        It does a matrix multiply, bias add, and then uses relu to nonlinearize.
        It also sets up name scoping so that the resultant graph is easy to read,
        and adds a number of summary ops.
        """
        # Adding a name scope ensures logical grouping of the layers in the graph.
        with tf.name_scope(layer_name):
              # This Variable will hold the state of the weights for the layer
            with tf.name_scope('weights'):
                weights = weight_variable([input_dim, output_dim])
                ###################
                ## for tensor board
                ##################
                variable_summaries(weights)
            with tf.name_scope('biases'):
                biases = bias_variable([output_dim])
                ##############
                ## tensorboard
                #############
                variable_summaries(biases)
            with tf.name_scope('Wx_plus_b'):
                preactivate = tf.matmul(input_tensor, weights) + biases
                ####tensorboard
                tf.summary.histogram('pre_activations', preactivate)
            activations = act(preactivate, name='activation')
            tf.summary.histogram('activations', activations)

            return activations

    
    
    #########################################################################
    ### now we build the graph 
    #########################################################################
    
    hidden1 = nn_layer(x, 784, 500, 'layer1')

    with tf.name_scope('dropout'):
        keep_prob = tf.placeholder(tf.float32)
        tf.summary.scalar('dropout_keep_probability', keep_prob)
        dropped = tf.nn.dropout(hidden1, keep_prob)

    # Do not apply softmax activation yet, see below.
    y = nn_layer(dropped, 500, 10, 'layer2', act=tf.identity) ## fully connected layer

    with tf.name_scope('cross_entropy'):
        diff = tf.nn.softmax_cross_entropy_with_logits(labels=y_, logits=y)
        with tf.name_scope('total'):
            cross_entropy = tf.reduce_mean(diff)
    
    ## for tensorfbaord
    tf.summary.scalar('cross_entropy', cross_entropy)

    with tf.name_scope('train'):
        train_step = tf.train.AdamOptimizer(FLAGS.learning_rate).minimize(
            cross_entropy)

    with tf.name_scope('accuracy'):
        with tf.name_scope('correct_prediction'):
            correct_prediction = tf.equal(tf.argmax(y, 1), tf.argmax(y_, 1))
        with tf.name_scope('accuracy'):
            accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
            
    tf.summary.scalar('accuracy', accuracy)
    
    ################################################
    # Merge all the summaries and write them out to /tmp/tensorflow/mnist/logs/mnist_with_summaries (by default)
    #################################################
    merged = tf.summary.merge_all()
    train_writer = tf.summary.FileWriter(FLAGS.log_dir + '/train', sess.graph)
    test_writer = tf.summary.FileWriter(FLAGS.log_dir + '/test')
    tf.global_variables_initializer().run()

    # Train the model, and also write summaries.
    # Every 10th step, measure test-set accuracy, and write test summaries
    # All other steps, run train_step on training data, & add training summaries

    def feed_dict(train):
        """Make a TensorFlow feed_dict: maps data onto Tensor placeholders."""
        if train or FLAGS.fake_data:
            xs, ys = mnist.train.next_batch(100, fake_data=FLAGS.fake_data)
            k = FLAGS.dropout
        else:
            xs, ys = mnist.test.images, mnist.test.labels
            k = 1.0
        return {x: xs, y_: ys, keep_prob: k}

    for i in range(FLAGS.max_steps):
        if i % 10 == 0:  # Record summaries and test-set accuracy
            summary, acc = sess.run([merged, accuracy], feed_dict=feed_dict(False))
            test_writer.add_summary(summary, i)
            print('Accuracy at step %s: %s' % (i, acc))
        else:  # Record train set summaries, and train
            if i % 100 == 99:  # Record execution stats
                run_options = tf.RunOptions(trace_level=tf.RunOptions.FULL_TRACE)
                run_metadata = tf.RunMetadata()
                summary, _ = sess.run([merged, train_step],
                                      feed_dict=feed_dict(True),
                                      options=run_options,
                                      run_metadata=run_metadata)
                train_writer.add_run_metadata(run_metadata, 'step%03d' % i)
                train_writer.add_summary(summary, i)  ## for tensorboard
                print('Adding run metadata for', i)
            else:  # Record a summary
                summary, _ = sess.run([merged, train_step], feed_dict=feed_dict(True))
                train_writer.add_summary(summary, i)  ## for tensorboard
            
    train_writer.close()
    test_writer.close()

# %%
def main(_):
    if tf.gfile.Exists(FLAGS.log_dir):
        tf.gfile.DeleteRecursively(FLAGS.log_dir)
    tf.gfile.MakeDirs(FLAGS.log_dir)
    train()


if __name__ == '__main__':
    parser = argparse.ArgumentParser()
    parser.add_argument('--fake_data', nargs='?', const=True, type=bool,
                      default=False,
                      help='If true, uses fake data for unit testing.')
    parser.add_argument('--max_steps', type=int, default=2000,
                      help='Number of steps to run trainer.')  ## will stop at step 2000
    parser.add_argument('--learning_rate', type=float, default=0.001,
                      help='Initial learning rate')
    parser.add_argument('--dropout', type=float, default=0.5,
                      help='Keep probability for training dropout.')
    parser.add_argument('--data_dir', type=str, default='./input_data',
                      help='Directory for storing input data')
    parser.add_argument('--log_dir', type=str, default='./logs/mnist_with_summaries',
                      help='Summaries log directory')
    FLAGS, unparsed = parser.parse_known_args()
    tf.app.run(main=main, argv=[sys.argv[0]] + unparsed)
# Out:
# Extracting ./input_data/train-images-idx3-ubyte.gz
# Extracting ./input_data/train-labels-idx1-ubyte.gz
# Extracting ./input_data/t10k-images-idx3-ubyte.gz
# Extracting ./input_data/t10k-labels-idx1-ubyte.gz
# Accuracy at step 0: 0.0685
# Accuracy at step 10: 0.6508
# Accuracy at step 20: 0.7926
# Accuracy at step 30: 0.8327
# Accuracy at step 40: 0.852
# Accuracy at step 50: 0.8525
# Accuracy at step 60: 0.8772
# Accuracy at step 70: 0.8877
# Accuracy at step 80: 0.8784
# Accuracy at step 90: 0.8906
# Adding run metadata for 99
# Accuracy at step 100: 0.903
# Accuracy at step 110: 0.9071
# Accuracy at step 120: 0.9111
# Accuracy at step 130: 0.9184
# Accuracy at step 140: 0.9182
# Accuracy at step 150: 0.9159
# Accuracy at step 160: 0.9206
# Accuracy at step 170: 0.9209
# Accuracy at step 180: 0.9188
# Accuracy at step 190: 0.9228
# Adding run metadata for 199
# Accuracy at step 200: 0.9241
# Accuracy at step 210: 0.929
# Accuracy at step 220: 0.9303
# Accuracy at step 230: 0.9312
# Accuracy at step 240: 0.9307
# Accuracy at step 250: 0.9316
# Accuracy at step 260: 0.9345
# Accuracy at step 270: 0.9327
# Accuracy at step 280: 0.9319
# Accuracy at step 290: 0.9342
# Adding run metadata for 299
# Accuracy at step 300: 0.9388
# Accuracy at step 310: 0.9399
# Accuracy at step 320: 0.9372
# Accuracy at step 330: 0.935
# Accuracy at step 340: 0.9421
# Accuracy at step 350: 0.9405
# Accuracy at step 360: 0.9368
# Accuracy at step 370: 0.9418
# Accuracy at step 380: 0.943
# Accuracy at step 390: 0.9439
# Adding run metadata for 399
# Accuracy at step 400: 0.9448
# Accuracy at step 410: 0.9427
# Accuracy at step 420: 0.9414
# Accuracy at step 430: 0.9471
# Accuracy at step 440: 0.9494
# Accuracy at step 450: 0.9481
# Accuracy at step 460: 0.9484
# Accuracy at step 470: 0.9479
# Accuracy at step 480: 0.9487
# Accuracy at step 490: 0.9481
# Adding run metadata for 499
# Accuracy at step 500: 0.9494
# Accuracy at step 510: 0.952
# Accuracy at step 520: 0.9517
# Accuracy at step 530: 0.9511
# Accuracy at step 540: 0.9526
# Accuracy at step 550: 0.9534
# Accuracy at step 560: 0.9538
# Accuracy at step 570: 0.9522
# Accuracy at step 580: 0.9531
# Accuracy at step 590: 0.953
# Adding run metadata for 599
# Accuracy at step 600: 0.9546
# Accuracy at step 610: 0.9532
# Accuracy at step 620: 0.954
# Accuracy at step 630: 0.9554
# Accuracy at step 640: 0.9562
# Accuracy at step 650: 0.957
# Accuracy at step 660: 0.9549
# Accuracy at step 670: 0.9547
# Accuracy at step 680: 0.9559
# Accuracy at step 690: 0.9548
# Adding run metadata for 699
# Accuracy at step 700: 0.9565
# Accuracy at step 710: 0.955
# Accuracy at step 720: 0.9554
# Accuracy at step 730: 0.955
# Accuracy at step 740: 0.9587
# Accuracy at step 750: 0.9574
# Accuracy at step 760: 0.9596
# Accuracy at step 770: 0.9579
# Accuracy at step 780: 0.9578
# Accuracy at step 790: 0.9607
# Adding run metadata for 799
# Accuracy at step 800: 0.9579
# Accuracy at step 810: 0.958
# Accuracy at step 820: 0.9587
# Accuracy at step 830: 0.9607
# Accuracy at step 840: 0.9601
# Accuracy at step 850: 0.958
# Accuracy at step 860: 0.9594
# Accuracy at step 870: 0.9613
# Accuracy at step 880: 0.9606
# Accuracy at step 890: 0.9618
# Adding run metadata for 899
# Accuracy at step 900: 0.9624
# Accuracy at step 910: 0.962
# Accuracy at step 920: 0.9607
# Accuracy at step 930: 0.9633
# Accuracy at step 940: 0.9623
# Accuracy at step 950: 0.9618
# Accuracy at step 960: 0.9626
# Accuracy at step 970: 0.9629
# Accuracy at step 980: 0.9641
# Accuracy at step 990: 0.9641
# Adding run metadata for 999
# Accuracy at step 1000: 0.9644
# Accuracy at step 1010: 0.9641
# Accuracy at step 1020: 0.9651
# Accuracy at step 1030: 0.9637
# Accuracy at step 1040: 0.9648
# Accuracy at step 1050: 0.9622
# Accuracy at step 1060: 0.9644
# Accuracy at step 1070: 0.9635
# Accuracy at step 1080: 0.9675
# Accuracy at step 1090: 0.9668
# Adding run metadata for 1099
# Accuracy at step 1100: 0.966
# Accuracy at step 1110: 0.9673
# Accuracy at step 1120: 0.9653
# Accuracy at step 1130: 0.9665
# Accuracy at step 1140: 0.9661
# Accuracy at step 1150: 0.9649
# Accuracy at step 1160: 0.966
# Accuracy at step 1170: 0.9658
# Accuracy at step 1180: 0.9644
# Accuracy at step 1190: 0.9641
# Adding run metadata for 1199
# Accuracy at step 1200: 0.9622
# Accuracy at step 1210: 0.9657
# Accuracy at step 1220: 0.9662
# Accuracy at step 1230: 0.9666
# Accuracy at step 1240: 0.9682
# Accuracy at step 1250: 0.9678
# Accuracy at step 1260: 0.9668
# Accuracy at step 1270: 0.9669
# Accuracy at step 1280: 0.9684
# Accuracy at step 1290: 0.9677
# Adding run metadata for 1299
# Accuracy at step 1300: 0.9686
# Accuracy at step 1310: 0.9688
# Accuracy at step 1320: 0.9682
# Accuracy at step 1330: 0.9686
# Accuracy at step 1340: 0.9698
# Accuracy at step 1350: 0.9685
# Accuracy at step 1360: 0.969
# Accuracy at step 1370: 0.9695
# Accuracy at step 1380: 0.9705
# Accuracy at step 1390: 0.9694
# Adding run metadata for 1399
# Accuracy at step 1400: 0.9681
# Accuracy at step 1410: 0.97
# Accuracy at step 1420: 0.9699
# Accuracy at step 1430: 0.9686
# Accuracy at step 1440: 0.9694
# Accuracy at step 1450: 0.9714
# Accuracy at step 1460: 0.9709
# Accuracy at step 1470: 0.9707
# Accuracy at step 1480: 0.97
# Accuracy at step 1490: 0.9686
# Adding run metadata for 1499
# Accuracy at step 1500: 0.9693
# Accuracy at step 1510: 0.9691
# Accuracy at step 1520: 0.9698
# Accuracy at step 1530: 0.9696
# Accuracy at step 1540: 0.97
# Accuracy at step 1550: 0.9708
# Accuracy at step 1560: 0.9706
# Accuracy at step 1570: 0.972
# Accuracy at step 1580: 0.9696
# Accuracy at step 1590: 0.9711
# Adding run metadata for 1599
# Accuracy at step 1600: 0.9715
# Accuracy at step 1610: 0.9705
# Accuracy at step 1620: 0.9729
# Accuracy at step 1630: 0.9711
# Accuracy at step 1640: 0.9709
# Accuracy at step 1650: 0.97
# Accuracy at step 1660: 0.97
# Accuracy at step 1670: 0.9692
# Accuracy at step 1680: 0.9716
# Accuracy at step 1690: 0.9718
# Adding run metadata for 1699
# Accuracy at step 1700: 0.972
# Accuracy at step 1710: 0.9718
# Accuracy at step 1720: 0.9701
# Accuracy at step 1730: 0.9721
# Accuracy at step 1740: 0.9713
# Accuracy at step 1750: 0.974
# Accuracy at step 1760: 0.9727
# Accuracy at step 1770: 0.972
# Accuracy at step 1780: 0.9729
# Accuracy at step 1790: 0.9721
# Adding run metadata for 1799
# Accuracy at step 1800: 0.9727
# Accuracy at step 1810: 0.9717
# Accuracy at step 1820: 0.9726
# Accuracy at step 1830: 0.9721
# Accuracy at step 1840: 0.9717
# Accuracy at step 1850: 0.9695
# Accuracy at step 1860: 0.9728
# Accuracy at step 1870: 0.9727
# Accuracy at step 1880: 0.9738
# Accuracy at step 1890: 0.9719
# Adding run metadata for 1899
# Accuracy at step 1900: 0.9725
# Accuracy at step 1910: 0.9731
# Accuracy at step 1920: 0.9738
# Accuracy at step 1930: 0.9723
# Accuracy at step 1940: 0.9734
# Accuracy at step 1950: 0.972
# Accuracy at step 1960: 0.9738
# Accuracy at step 1970: 0.9734
# Accuracy at step 1980: 0.9732
# Accuracy at step 1990: 0.9736
# Adding run metadata for 1999
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /Users/huang/anaconda3/envs/tensorflow/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2889: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
